# %% [markdown]
# <a href="https://colab.research.google.com/github/67TUFFMANGOES/COMSCI/blob/main/FA2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
num3 = float(input("Enter third number: "))
biggest_number = num1

if num2 > biggest_number:
    biggest_number = num2

if num3 > biggest_number:
    biggest_number = num3

print(f"The biggest number is: {biggest_number}")
# Out:
# Enter first number: 4
# Enter second number: 2
# Enter third number: 3
# The biggest number is: 4.0
